# %% [markdown]
# ## Imports & Path

# %%
import os, sys
sys.path.append(os.path.abspath(".."))

import pandas as pd
import matplotlib.pyplot as plt

from src.data_loader import MarketDataConfig, fetch_prices, compute_returns
from src.portfolio import Portfolio, portfolio_returns
from src.var_models import historical_var, parametric_var_normal, parametric_var_ewma_normal, parametric_var_cov_matrix, historical_es, component_var_cov_matrix
from src.backtest import var_exceptions, exception_summary, exception_table, kupiec_test_uc
from src.plots import plot_var_multi
from src.scaling import scale_to_dollars

# %% [markdown]
# ## Config & Data

# %%
cfg = MarketDataConfig(
    tickers=["SPY", "TLT", "GLD", "UUP"],
    start="2015-01-01",
    use_log_returns=True
)

prices = fetch_prices(cfg)
rets = compute_returns(prices, use_log=cfg.use_log_returns)

prices.tail(), rets.tail()
# Out:
# (Ticker             GLD         SPY        TLT        UUP
#  Date
#  2026-02-12  451.390015  681.270020  89.230003  26.820000
#  2026-02-13  462.619995  681.750000  89.720001  26.820000
#  2026-02-17  448.200012  682.849976  89.870003  26.910000
#  2026-02-18  458.279999  686.289978  89.529999  27.080000
#  2026-02-19  457.379913  686.289978  89.657303  27.100201,
#  Ticker           GLD       SPY       TLT       UUP
#  Date
#  2026-02-12 -0.035346 -0.015569  0.013199 -0.000373
#  2026-02-13  0.024574  0.000704  0.005476  0.000000
#  2026-02-17 -0.031666  0.001612  0.001670  0.003350
#  2026-02-18  0.022241  0.005025 -0.003790  0.006297
#  2026-02-19 -0.001966  0.000000  0.001421  0.000746)

# %% [markdown]
# ## Portfolio

# %%
port = Portfolio(weights={"SPY": 0.4, "TLT": 0.3, "GLD": 0.2, "UUP": 0.1})
pret = portfolio_returns(rets, port)
NOTIONAL = 10_000_000  # $10mm demo notional 
pnl = scale_to_dollars(pret, NOTIONAL) # use helper to scale pre-trade into dollars  

pret.describe()
# Out:
# count    2798.000000
# mean        0.000303
# std         0.005437
# min        -0.045451
# 25%        -0.002395
# 50%         0.000619
# 75%         0.003174
# max         0.049112
# Name: portfolio_return, dtype: float64

# %% [markdown]
# ## VaR Models

# %%
TRADING_DAYS = 252

# Historical
var95_hist = historical_var(pret, window=TRADING_DAYS, alpha=0.05)
var95_hist_dollars = scale_to_dollars(var95_hist, NOTIONAL)
var99_hist = historical_var(pret, window=TRADING_DAYS, alpha=0.01)
var99_hist_dollars = scale_to_dollars(var99_hist, NOTIONAL)

# Parametric
var95_param = parametric_var_normal(pret, window=TRADING_DAYS, alpha=0.05, use_mean=True)
var95_param_dollars = scale_to_dollars(var95_param, NOTIONAL)
var99_param = parametric_var_normal(pret, window=TRADING_DAYS, alpha=0.01, use_mean=True)
var99_param_dollars = scale_to_dollars(var99_param, NOTIONAL)

# Covariance Matrix
var95_cov = parametric_var_cov_matrix(rets, port.weights, window=TRADING_DAYS, alpha=0.05, use_mean=True)
var95_cov_dollars = scale_to_dollars(var95_cov, NOTIONAL)
var99_cov = parametric_var_cov_matrix(rets, port.weights, window=TRADING_DAYS, alpha=0.01, use_mean=True)
var99_cov_dollars = scale_to_dollars(var99_cov, NOTIONAL)

# EWMA VaR (return space)
var95_ewma = parametric_var_ewma_normal(pret, alpha=0.05, lam=0.94, use_mean=False, burn_in=30)
var99_ewma = parametric_var_ewma_normal(pret, alpha=0.01, lam=0.94, use_mean=False, burn_in=30)

# Scale to dollars (to match pnl and other VaR_$ series)
var95_ewma_dollars = scale_to_dollars(var95_ewma, NOTIONAL)
var99_ewma_dollars = scale_to_dollars(var99_ewma, NOTIONAL)

pd.concat(
    [pnl.rename("P&L_$"),
     var95_hist_dollars.rename("VaR95_hist_$"),
     var95_param_dollars.rename("VaR95_param_$"),
     var95_cov_dollars.rename("VaR95_cov_$"),
     var95_ewma_dollars.rename("VaR95_ewma_$")],
    axis=1
).dropna().head()

# Expected Shortfall (Historical ES / CVaR)
# ES is the average loss conditional on being in the worst alpha% of outcomes.
es95 = historical_es(pret, window=TRADING_DAYS, alpha=0.05)
es99 = historical_es(pret, window=TRADING_DAYS, alpha=0.01)

es95_dollars = scale_to_dollars(es95, NOTIONAL)
es99_dollars = scale_to_dollars(es99, NOTIONAL)

# Quick sanity check: ES should be more negative than VaR (same confidence level)
es_check = pd.concat(
    [var95_hist_dollars.rename("VaR95_$"), es95_dollars.rename("ES95_$"),
     var99_hist_dollars.rename("VaR99_$"), es99_dollars.rename("ES99_$")],
    axis=1
).dropna()

es_check.tail()

# ES Summary Snapshot (latest)
latest_es = es_check.iloc[-1]
print("Latest tail metrics (Historical):")
print(f"VaR95: {latest_es['VaR95_$']:,.0f} | ES95: {latest_es['ES95_$']:,.0f}")
print(f"VaR99: {latest_es['VaR99_$']:,.0f} | ES99: {latest_es['ES99_$']:,.0f}")

# Component VaR (Cov-Matrix Parametric)
comp95 = component_var_cov_matrix(rets, port.weights, window=TRADING_DAYS, alpha=0.05)
comp95_dollars = comp95 * NOTIONAL  # scale contributions to dollars

# Latest contributions snapshot
latest = comp95_dollars.dropna().iloc[-1].sort_values()
latest.to_frame("component_VaR95_$")
# Out:
# Latest tail metrics (Historical):
# VaR95: -93,042 | ES95: -147,407
# VaR99: -226,877 | ES99: -238,971
#      component_VaR95_$
# SPY      -64749.222734
# GLD      -26664.622167
# TLT      -14214.842261
# UUP         433.962750

# %% [markdown]
# ## Backtest Summaries

# %%
b95 = var_exceptions(pnl, var95_hist_dollars)
b99 = var_exceptions(pnl, var99_hist_dollars)
b95_ewma = var_exceptions(pnl, var95_ewma_dollars)
b99_ewma = var_exceptions(pnl, var99_ewma_dollars)
b95_cov = var_exceptions(pnl, var95_cov_dollars)
b99_cov = var_exceptions(pnl, var99_cov_dollars)

sum95 = exception_summary(b95, alpha=0.05)
sum99 = exception_summary(b99, alpha=0.01)
sum95_ewma = exception_summary(b95_ewma, alpha=0.05)
sum99_ewma = exception_summary(b99_ewma, alpha=0.01)
sum95_cov = exception_summary(b95_cov, 0.05)
sum99_cov = exception_summary(b99_cov, 0.01)

pd.DataFrame([sum95, sum95_ewma, sum95_cov, sum99, sum99_ewma, sum99_cov],
            index=["Hist_95", "EWMA_95","Cov_95", "Hist_99", "EWMA_99", "Cov_99"])
# Out:
#          n_obs  alpha  breaches  expected_breaches  breach_rate
# Hist_95   2547   0.05       128             127.35     0.050255
# EWMA_95   2768   0.05       130             138.40     0.046965
# Cov_95    2547   0.05       123             127.35     0.048292
# Hist_99   2547   0.01        33              25.47     0.012956
# EWMA_99   2768   0.01        55              27.68     0.019870
# Cov_99    2547   0.01        51              25.47     0.020024

# %% [markdown]
# ## Kupiec Test

# %%
# use helper for Kupiec Test
kup95 = kupiec_test_uc(b95, alpha=0.05)
kup99 = kupiec_test_uc(b99, alpha=0.01)
kup95_ewma = kupiec_test_uc(b95_ewma, alpha=0.05)
kup99_ewma = kupiec_test_uc(b99_ewma, alpha=0.01)
kup95_cov = kupiec_test_uc(b95_cov, 0.05)
kup99_cov = kupiec_test_uc(b99_cov, 0.01)

print(pd.DataFrame([kup95, kup95_ewma, kup95_cov, kup99, kup99_ewma, kup99_cov], index=["Kup_Roll_95", "Kup_EWMA_95", "Kup_Cov_95", "Kup_Roll_99", "Kup_EWMA_99", "Kup_Cov_99"]),"\n")

def interpret_kupiec(res, sig=0.05):
    return "FAIL (too many/few exceptions)" if res["p_value"] < sig else "PASS (coverage consistent)"

print("Kupiec_roll 95:", interpret_kupiec(kup95), "| p-value:", kup95["p_value"])
print("Kupiec_ewma 95:", interpret_kupiec(kup95_ewma), "| p-value:", kup95_ewma["p_value"])
print("Kupiec_cov 95:", interpret_kupiec(kup95_cov), "| p-value:", kup95_cov["p_value"],"\n")
print("Kupiec_roll 99:", interpret_kupiec(kup99), "| p-value:", kup99["p_value"])
print("Kupiec_ewma 99:", interpret_kupiec(kup99_ewma), "| p-value:", kup99_ewma["p_value"])
print("Kupiec_cov 99:", interpret_kupiec(kup99_cov), "| p-value:", kup99_cov["p_value"])
# Out:
#              n_obs  breaches  alpha  breach_rate      lr_uc   p_value
# Kup_Roll_95   2547       128   0.05     0.050255   0.003487  0.952914
# Kup_EWMA_95   2768       130   0.05     0.046965   0.547270  0.459435
# Kup_Cov_95    2547       123   0.05     0.048292   0.158124  0.690890
# Kup_Roll_99   2547        33   0.01     0.012956   2.056923  0.151516
# Kup_EWMA_99   2768        55   0.01     0.019870  21.161816  0.000004
# Kup_Cov_99    2547        51   0.01     0.020024  20.020446  0.000008
#
# Kupiec_roll 95: PASS (coverage consistent) | p-value: 0.9529141469839706
# Kupiec_ewma 95: PASS (coverage consistent) | p-value: 0.4594351804567115
# Kupiec_cov 95: PASS (coverage consistent) | p-value: 0.6908900413179357
#
# Kupiec_roll 99: PASS (coverage consistent) | p-value: 0.1515158470152953
# Kupiec_ewma 99: FAIL (too many/few exceptions) | p-value: 4.2209074274657254e-06
# Kupiec_cov 99: FAIL (too many/few exceptions) | p-value: 7.661853251295092e-06

# %% [markdown]
# ## Exception Table

# %%
# Use helper to get exceptions
exc95 = exception_table(pnl, var95_hist_dollars, top_n=1000)
exc99 = exception_table(pnl, var99_hist_dollars, top_n=1000)

## Save all exceptions to csv files
os.makedirs("../outputs", exist_ok=True)
exc95.to_csv("../outputs/var95_exceptions.csv")
exc99.to_csv("../outputs/var99_exceptions.csv")
print("Saved:", "../outputs/var95_exceptions.csv", "../outputs/var99_exceptions.csv\n")

## Print worst day(s) data
worst_day_95 = exc95.index[0] if len(exc95) else None
if worst_day_95:
    row = exc95.loc[worst_day_95]
    print(f"Worst 95% VaR breach day: {worst_day_95.date()}")
    print(f"Realized P&L: ${row['realized']:,.0f}")
    print(f"VaR threshold: ${row['var']:,.0f}")
    print(f"Exceedance (Realized - VaR): ${row['exceedance']:,.0f}\n")
else:
    print("No breaches found in sample (unexpected for long history).")
print("95% Top 5 worst days\n", exc95.head(), "\n")

worst_day_99 = exc99.index[0] if len(exc99) else None
if worst_day_99:
    row = exc99.loc[worst_day_99]
    print(f"Worst 99% VaR breach day: {worst_day_99.date()}")
    print(f"Realized P&L: ${row['realized']:,.0f}")
    print(f"VaR threshold: ${row['var']:,.0f}")
    print(f"Exceedance (Realized - VaR): ${row['exceedance']:,.0f}\n")
else:
    print("No breaches found in sample (unexpected for long history).")
print("99% Top 5 worst days", exc99.head())
# Out:
# Saved: ../outputs/var95_exceptions.csv ../outputs/var99_exceptions.csv
#
# Worst 95% VaR breach day: 2020-03-12
# Realized P&L: $-454,505
# VaR threshold: $-59,408
# Exceedance (Realized - VaR): $-395,097
#
# 95% Top 5 worst days
#                   realized            var  breach     exceedance
# Date
# 2020-03-12 -454505.061061  -59407.964000    True -395097.097061
# 2020-03-18 -407228.741160  -64188.316404    True -343040.424756
# 2020-03-16 -330902.274369  -61373.957777    True -269528.316593
# 2020-03-11 -317987.898368  -57752.272491    True -260235.625877
# 2022-06-13 -294357.248742 -105287.340630    True -189069.908111
#
# Worst 99% VaR breach day: 2020-03-12
# Realized P&L: $-454,505
# VaR threshold: $-203,837
# Exceedance (Realized - VaR): $-250,668
#
# 99% Top 5 worst days                  realized            var  breach     exceedance
# Date
# 2020-03-12 -454505.061061 -203836.653244    True -250668.407817
# 2020-03-18 -407228.741160 -324315.942609    True  -82912.798551
# 2020-03-16 -330902.274369 -284612.621310    True  -46289.653060
# 2020-03-11 -317987.898368 -151513.273811    True -166474.624557
# 2022-06-13 -294357.248742 -168743.632092    True -125613.616649

# %% [markdown]
# ## Plots (in $)

# %%
plot_var_multi(
    returns=pnl,
    var_lines={
        "VaR95 Historical": var95_hist_dollars,
        "VaR95 Parametric (Rolling Normal)": var95_param_dollars,
        "VaR95 EWMA (Normal)": var95_ewma_dollars,
        "VaR95 Cov-Matrix Parametric": var95_cov_dollars,
    },
    title="Portfolio $ P&L vs 95% VaR (Historical, Parametric, EWMA, Cov-Matrix)",
    outpath="../outputs/figures/var_95_overlay_all.png",
    mark_breaches_against="VaR95 Historical",
)

plot_var_multi(
    returns=pnl,
    var_lines={
        "VaR99 Historical": var99_hist_dollars,
        "VaR99 Parametric (Rolling Normal)": var99_param_dollars,
        "VaR99 EWMA (Normal)": var99_ewma_dollars,
        "VaR99 Cov-Matrix Parametric": var99_cov_dollars,
    },
    title="Portfolio $ P&L vs 99% VaR (Historical, Parametric, EWMA, Cov-Matrix)",
    outpath="../outputs/figures/var_99_overlay_all.png",
    mark_breaches_against="VaR99 Historical",
)

df = pd.concat([pnl.rename("P&L_$"),
                var95_hist_dollars.rename("VaR95_$"),
                es95_dollars.rename("ES95_$")], axis=1).dropna()

plt.figure()
plt.plot(df.index, df["P&L_$"], label="P&L")
plt.plot(df.index, df["VaR95_$"], label="VaR 95%")
plt.plot(df.index, df["ES95_$"], label="ES 95%")
plt.title("Portfolio $ P&L vs Historical VaR and ES (95%)")
plt.legend()
plt.tight_layout()
plt.show()

latest = comp95_dollars.dropna().iloc[-1]
plt.figure()
latest.plot(kind="bar")
plt.title("Latest Component VaR 95% ($) by Asset")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Pre-Trade Impact (Simple)

# %%
port_new = Portfolio(weights={"SPY": 0.6, "TLT": 0.2, "GLD": 0.1, "UUP": 0.1})

pret_new = portfolio_returns(rets, port_new)
pnl_new = scale_to_dollars(pret_new, NOTIONAL)

var95_hist_new = historical_var(pret_new, window=TRADING_DAYS, alpha=0.05)
var95_param_new = parametric_var_normal(pret_new, window=TRADING_DAYS, alpha=0.05, use_mean=True)
var99_hist_new = historical_var(pret_new, window=TRADING_DAYS, alpha=0.01)
var99_param_new = parametric_var_normal(pret_new, window=TRADING_DAYS, alpha=0.01, use_mean=True)

var95_hist_new_dollars = scale_to_dollars(var95_hist_new, NOTIONAL)
var95_param_new_dollars = scale_to_dollars(var95_param_new, NOTIONAL)
var99_hist_new_dollars = scale_to_dollars(var99_hist_new, NOTIONAL)
var99_param_new_dollars = scale_to_dollars(var99_param_new, NOTIONAL)

comparison = pd.DataFrame({
    "VaR95_hist_old_$": var95_hist_dollars.dropna().round(2),
    "VaR95_hist_new_$": var95_hist_new_dollars.dropna().round(2),
    "VaR95_param_old_$": var95_param_dollars.dropna().round(2),
    "VaR95_param_new_$": var95_param_new_dollars.dropna().round(2),
    "VaR99_hist_old_$": var99_hist_dollars.dropna().round(2),
    "VaR99_hist_new_$": var99_hist_new_dollars.dropna().round(2),
    "VaR99_param_old_$": var99_param_dollars.dropna().round(2),
    "VaR99_param_new_$": var99_param_new_dollars.dropna().round(2),
}).dropna()

comparison.tail().round(2)
# Out:
#             VaR95_hist_old_$  VaR95_hist_new_$  VaR95_param_old_$  \
# Date
# 2026-02-12          -93042.1        -110004.37          -98761.92
# 2026-02-13          -93042.1        -110004.37          -98309.48
# 2026-02-17          -93042.1        -110004.37          -98593.87
# 2026-02-18          -93042.1        -110004.37          -98404.61
# 2026-02-19          -93042.1        -110004.37          -98445.06
#
#             VaR95_param_new_$  VaR99_hist_old_$  VaR99_hist_new_$  \
# Date
# 2026-02-12         -122918.76        -226876.97        -236788.13
# 2026-02-13         -122524.73        -226876.97        -236788.13
# 2026-02-17         -122633.58        -226876.97        -236788.13
# 2026-02-18         -122482.48        -226876.97        -236788.13
# 2026-02-19         -122523.76        -226876.97        -236788.13
#
#             VaR99_param_old_$  VaR99_param_new_$
# Date
# 2026-02-12         -142420.45         -176065.33
# 2026-02-13         -141977.06         -175647.32
# 2026-02-17         -142130.31         -175615.63
# 2026-02-18         -141988.50         -175498.20
# 2026-02-19         -142029.24         -175538.90

# %% [markdown]
# ## Summary of Pre-Trade Change

# %%
latest = comparison.iloc[-1]
delta_hist_95 = latest["VaR95_hist_new_$"] - latest["VaR95_hist_old_$"]
delta_param_95 = latest["VaR95_param_new_$"] - latest["VaR95_param_old_$"]
delta_hist_99 = latest["VaR99_hist_new_$"] - latest["VaR99_hist_old_$"]
delta_param_99 = latest["VaR99_param_new_$"] - latest["VaR99_param_old_$"]

print("95% VaR Pre-Trade Change")
print(f"VaR95_hist_old_$: {latest['VaR95_hist_old_$']:.2f}")
print(f"VaR95_hist_new_$: {latest['VaR95_hist_new_$']:.2f}")
print(f"VaR95_param_old_$: {latest['VaR95_param_old_$']:.2f}")
print(f"VaR95_param_new_$: {latest['VaR95_param_new_$']:.2f}")
print(f"delta_hist_$: {delta_hist_95:.2f}")
print(f"delta_param_$: {delta_param_95:.2f}\n")
print("99% VaR Pre-Trade Change")
print(f"VaR99_hist_old_$: {latest['VaR99_hist_old_$']:.2f}")
print(f"VaR99_hist_new_$: {latest['VaR99_hist_new_$']:.2f}")
print(f"VaR99_param_old_$: {latest['VaR99_param_old_$']:.2f}")
print(f"VaR99_param_new_$: {latest['VaR99_param_new_$']:.2f}")
print(f"delta_hist_$: {delta_hist_99:.2f}")
print(f"delta_param_$: {delta_param_99:.2f}")
# Out:
# 95% VaR Pre-Trade Change
# VaR95_hist_old_$: -93042.10
# VaR95_hist_new_$: -110004.37
# VaR95_param_old_$: -98445.06
# VaR95_param_new_$: -122523.76
# delta_hist_$: -16962.27
# delta_param_$: -24078.70
#
# 99% VaR Pre-Trade Change
# VaR99_hist_old_$: -226876.97
# VaR99_hist_new_$: -236788.13
# VaR99_param_old_$: -142029.24
# VaR99_param_new_$: -175538.90
# delta_hist_$: -9911.16
# delta_param_$: -33509.66
